# %% [markdown]
# <div style="text-align: center; font-family: 'Georgia', serif; padding: 30px 60px; border-bottom: 2px solid #333; margin-bottom: 20px;">
#
# <h1 style="font-size: 1.6em; font-weight: bold; margin-bottom: 8px;">
# Análise Exploratória do Dataset Tic-Tac-Toe:<br>Arquivo, Distribuição de Classes e Estrutura dos Atributos
# </h1>
#
# <p style="font-size: 1.0em; color: #444; margin: 6px 0;">
# <strong>Júlia Augustini, Pedro Tomielo, Rodrigo Gonçalves</strong>
# </p>
#
# <p style="font-size: 0.9em; color: #555; margin: 4px 0;">
# Pontifícia Universidade Católica &mdash; Cadeira: Inteligência Artificial
# </p>
#
# <p style="font-size: 0.85em; color: #666; margin: 4px 0;">
# Abril de 2026
# </p>
#
# </div>
#
# ---
#
# **Resumo.** Este notebook apresenta a análise exploratória de dados (EDA) do conjunto *Tic-Tac-Toe Endgame* (Aha, 1991), composto por 958 configurações legais de fim de partida do jogo da velha. O objetivo é compreender a estrutura dos dados, a distribuição das classes e as características dos atributos categóricos antes da etapa de modelagem preditiva. São investigadas a frequência de cada valor por posição do tabuleiro, o balanceamento entre classes (*win* vs. *no-win* para o jogador X) e possíveis correlações entre posições estratégicas e o resultado da partida.
#
# **Palavras-chave:** Análise Exploratória de Dados, Classificação, Jogo da Velha, Aprendizado de Máquina, UCI Repository.
#
# ---

# %%
# O arquivo .data é basicamente um csv sem cabeçalho, o que significa que temos que criar um
# acredito que posicoes de 1-9 como cabecalho sao a melhor opcao
import pandas as pd
colunas = [f"pos_{i}" for i in range(1, 10)] + ["classe"]

df = pd.read_csv("../data/raw/tic-tac-toe.data", header=None, names=colunas)

# %%
df.describe()
# Out:
#        pos_1 pos_2 pos_3 pos_4 pos_5 pos_6 pos_7 pos_8 pos_9    classe
# count    958   958   958   958   958   958   958   958   958       958
# unique     3     3     3     3     3     3     3     3     3         2
# top        x     x     x     x     x     x     x     x     x  positive
# freq     418   378   418   378   458   378   418   378   418       626

# %%
df['classe'].hist()
# Out:
# <Axes: >
